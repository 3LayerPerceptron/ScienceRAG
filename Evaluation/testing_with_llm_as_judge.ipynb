# %% [markdown]
# ### Тестирование с помощью LLM As Judge

# %%
from json import load

# %%
#!pip install langchain langchain-core langchain-mistralai pydantic

# %%
with open('val_retrieve_responses.json', 'r') as f:
    val_retrieve_responses = load(f)
with open('val_generate_answers.json', 'r') as f:
    val_generate_answers = load(f)
with open('val_generate_ground_truths.json', 'r') as f:
    val_generate_ground_truths = load(f)
with open('val_queries.json', 'r') as f:
    val_queries = load(f)

# %%
limit = 3
retriever_contexts = {}
for k, v in val_retrieve_responses.items():
    contexts = []
    for i in range(limit):
        context = v[i]['content']
        contexts.append(context)
    retriever_contexts[k] = contexts

# %%
import dotenv
import os
dotenv.load_dotenv('.env.host')

os.environ['MISTRAL_API_KEY'] = os.getenv('LLM_API_KEY')

# %%
from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate

judge = ChatMistralAI(
    model="mistral-large-latest",  # или другой judge
    temperature=0
)

# %%
import numpy as np
from typing import List
from pydantic import BaseModel, Field


from tqdm import tqdm

# ---------- Faithfulness ----------
class FaithfulnessResult(BaseModel):
    faithfulness: float = Field(ge=0.0, le=1.0)
    unsupported_claims: List[str] = Field(default_factory=list)

faith_prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a strict RAG evaluator. Use ONLY the provided context. "
     "If the answer contains any factual claim not supported by the context, it is unsupported. "
     "Return JSON only."),
    ("human",
     "Question:\n{question}\n\n"
     "Context:\n{context}\n\n"
     "Answer:\n{answer}\n\n"
     "Output JSON with faithfulness in [0,1] and unsupported_claims.")
])

faith_chain = faith_prompt | judge.with_structured_output(FaithfulnessResult)

# ---------- Correctness ----------
class CorrectnessResult(BaseModel):
    correctness: float = Field(ge=0.0, le=1.0)
    major_errors: List[str] = Field(default_factory=list)

corr_prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a strict evaluator. Compare the answer to the ground truth. "
     "Return JSON only."),
    ("human",
     "Question:\n{question}\n\n"
     "Ground truth:\n{ground_truth}\n\n"
     "Answer:\n{answer}\n\n"
     "Output JSON with correctness in [0,1] and major_errors.")
])

corr_chain = corr_prompt | judge.with_structured_output(CorrectnessResult)

# ---------- Dataset-level scoring ----------
def eval_dataset(qids, questions, contexts, answers, ground_truths, tau=0.8):
    faith_scores, corr_scores = [], []

    for qid in tqdm(qids):
        ctx = "\n\n---\n\n".join(contexts[qid])  # top-3 chunks as strings
        ans = answers[qid]
        q   = questions[qid]
        gt  = ground_truths[qid]

        faith = faith_chain.invoke({"question": q, "context": ctx, "answer": ans})
        corr  = corr_chain.invoke({"question": q, "ground_truth": gt, "answer": ans})

        faith_scores.append(faith.faithfulness)
        corr_scores.append(corr.correctness)

    mean_faith = float(np.mean(faith_scores))
    mean_corr  = float(np.mean(corr_scores))
    task_success = float(np.mean([c >= tau for c in corr_scores]))
    halluc_rate  = 1.0 - mean_faith

    return {
        "mean_correctness": mean_corr,
        "task_success_rate": task_success,
        "mean_faithfulness": mean_faith,
        "hallucination_rate": halluc_rate,
    }

# %%
val_queries
# Out:
# {'3a004357-19ab-4ed6-b60c-02e419657cc4': {'query': 'What is the concept of location-class independence in object detection?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '0dd5fa73-c74a-43cd-815b-5c1cb8d3d50a': {'query': 'Why is post-calibrated softmax adjustment (PCSA) important in handling class imbalances?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  'be608e3f-d284-4b13-b37d-5dd2571a8572': {'query': 'What does the term $p(y, o, u)$ represent in object detection?',
#   'type': 'extractive',
#   'source': 'text'},
#  'ed761078-1f4b-45ec-a3f1-7084d2825171': {'query': 'Is there any significant relationship between geolocation error and performance in the updated GEDI dataset?',
#   'type': 'extractive',
#   'source': 'text'},
#  '5a7d0a0b-d63d-4095-8c50-6a2f8f453554': {'query': 'How do bootstrap variance estimators compare to true variances in statistical studies?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  'dffc3d17-6be2-4ce4-81b3-5ca9d57d8abb': {'query': 'How is land cover classified in the Copernicus Global Land Service map?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  'a078059a-08f7-4bde-8488-329b3db39123': {'query': 'How does the structure multivector (SMV) improve spatial phase estimation?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '637fdb28-12fb-472d-8d35-ea68a4ab77f6': {'query': 'Why is accurate estimation of Above Ground Biomass important for global challenges?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'e80ec180-ea50-453b-bdce-96e0b346acaa': {'query': 'How can calibration techniques enhance the performance of machine learning models for detecting rare objects?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '80e9d110-82af-41e5-8ad4-f084910c506e': {'query': 'Are there any interband contributions in the hopping terms for WTe2?',
#   'type': 'extractive',
#   'source': 'text'},
#  '2edf284b-1689-4dc7-89d0-321935d60f18': {'query': 'What role does channel estimation play in enhancing the performance of smart applications in 6G networks?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'f3b05e20-1008-43c6-9e21-ff8fed85156f': {'query': 'What do isotonic Single-Index Models (SIMs) allow for in comparison to GLMs?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '0faca208-1f08-43ed-ace7-46ac1956e879': {'query': 'Can the Stubborn Nakamoto protocol regain liveness after an attack?',
#   'type': 'extractive',
#   'source': 'text'},
#  '8c270ba7-7698-4fe5-82dc-4790162878e0': {'query': 'How does the SmoothInfo method improve upon traditional fractal dimension calculation techniques?',
#   'type': 'abstractive',
#   'source': 'text-table'},
#  '3e072125-e130-438c-b264-0bfb622cdf65': {'query': 'How are foreground and background predictions decoupled in binary classifiers?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'b4595669-6205-48df-8fe6-c4a26a0ddfad': {'query': 'Can a PoS protocol regain liveness once an honest majority is restored?',
#   'type': 'extractive',
#   'source': 'text'},
#  'ac71f2cd-5415-4a58-a032-634b08c2d8d9': {'query': 'Is the function $\\phi$ Hadamard directionally differentiable for all $\\theta \\in \\mathbb{R}^{K}$?',
#   'type': 'extractive',
#   'source': 'text'},
#  '99f847b7-45cd-427c-8b12-70f3f293a025': {'query': 'What is the purpose of the FRACAL method in object detection?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '4f54beeb-4760-487f-97dd-b794b9534c4c': {'query': 'Are closed forests the largest land cover type at the global scale?',
#   'type': 'extractive',
#   'source': 'text-table-image'},
#  '4c1167ec-4f88-4e1c-a802-ce7ebf0e5f2a': {'query': 'How does Batch-DiffTune enhance robustness compared to DiffTune?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '0817759c-e9ca-49a4-ba97-5f96044a9cde': {'query': 'What is required for a causal representation to exist for a given $\\tau_{0}$?',
#   'type': 'extractive',
#   'source': 'text'},
#  'a0f6b046-11ba-4995-a431-7f716d9be58a': {'query': 'Can a weighted estimand always correspond to the target estimand a researcher is interested in?',
#   'type': 'extractive',
#   'source': 'text'},
#  '01063042-ba62-4c90-8cb6-9ac5df7adb2a': {'query': 'What are the four main concepts defined by XAI?',
#   'type': 'extractive',
#   'source': 'text'},
#  '0ba242ae-45e8-48d2-ad77-05c88d42f203': {'query': 'What is the significance of estimating regression coefficients in high-dimensional GLMs?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '89c10cda-3293-4d74-82a0-9ada2e548949': {'query': 'Is the missing data mechanism assumed to be Missing-At-Random (MAR)?',
#   'type': 'extractive',
#   'source': 'text'},
#  'ebafa50b-c5cc-4196-80f3-8aa3a348a5c4': {'query': 'What type of data does PALSAR-2 capture?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  '6f1e268c-3189-47a9-9500-fd6b10d27c62': {'query': 'What benefits does the XAI-CHEST framework offer over traditional deep learning-based channel estimation methods?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'b88cab41-973b-4b16-9f5f-0d7aca565495': {'query': 'How often is Sentinel-2 data collected for use in the AGBD dataset?',
#   'type': 'extractive',
#   'source': 'text-table'},
#  'aa7c0f53-8ac0-4f2a-9f13-1c35f6a6c457': {'query': 'Are gradient-based methods in XAI dependent on back-propagation?',
#   'type': 'extractive',
#   'source': 'text'},
#  'f1f407f3-21b0-481d-93d5-3e8010fd46bd': {'query': 'What is the impact of unilateral divorce laws on female suicide rates in the U.S.?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  '8b0c6dc2-ffd5-4977-a56b-63c19f0c5e71': {'query': 'At what temperature does the validity of generated molecules remain consistently high?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  '842814ff-0d06-47a2-b79f-8ace2cf7d523': {'query': 'Is it possible for an estimand to have no causal representation over any regular subpopulation of $W_0$?',
#   'type': 'extractive',
#   'source': 'text'},
#  'e8a2456e-90ce-488f-befc-521e1f75592c': {'query': 'What is the purpose of the TPN in model-based control?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '71095b8c-1820-4ce6-81e4-2f8ebc84af96': {'query': 'What is the goal in maximizing $\\mathbb{P}\\left(W^{*}=1 \\mid W^{\\prime}=1\\right)$?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '5f070211-03b6-4151-b128-7665d0538944': {'query': 'How many qubits are needed to simulate the properties of a Hubbard model on an \\(N_x \\times N_y\\) square lattice?',
#   'type': 'extractive',
#   'source': 'text'},
#  'd9f19950-b63d-4b26-9e26-c12a8af30c92': {'query': 'How does the fine-scale fingerprint registration method perform under varying noise conditions?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  '05503af0-a4f2-4913-b78d-fbe630cc1396': {'query': 'Why is coherence important in estimating local structures within interference patterns?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '7f6bab1b-3d4e-45d0-840e-92591419f931': {'query': "Can small miners contribute to a tragedy of the commons scenario in Bitcoin's protocol?",
#   'type': 'extractive',
#   'source': 'text'},
#  '6af3388a-f97d-47b4-b9ab-92640dd11d41': {'query': 'What challenges arise when tuning control parameters for varying robot tasks?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'a5baa057-111a-43d4-a8f6-92aeaa618934': {'query': 'What is the process for generating trajectory datasets for quadrotors?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '4e78e3c2-d10c-4bbb-a908-44db042ee83f': {'query': 'What role do pilot subcarriers play in improving channel estimation accuracy?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  'fea1e036-994d-4ece-b172-296d94af1912': {'query': 'What is the significance of internal validity in weighted estimands?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'aaef5819-4158-4103-a7e1-183a7a95b9b3': {'query': 'What is the significance of excitonic ground states in two-dimensional materials?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  'fc371482-b024-4274-bd67-d36c3620829b': {'query': 'Is consistency one of the properties required for correctness in consensus protocols?',
#   'type': 'extractive',
#   'source': 'text'},
#  '53d86046-8b6a-4a48-8619-26b98338494e': {'query': 'What is the Task-Parameter Nexus approach in model-based control?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '0eac8758-02f6-4ec3-82d9-3db7d406df47': {'query': 'Can TPN infer parameters for tasks not seen during training?',
#   'type': 'extractive',
#   'source': 'text'},
#  'a78a905f-2df3-4f24-a145-577e0756bc70': {'query': 'What is the target of inference in the estimation of the Generalized Covariance Measure (GCM)?',
#   'type': 'extractive',
#   'source': 'text'},
#  '8224e561-7ff0-4844-962d-b60d68e27f4c': {'query': 'How does the fidelity of VQE compare to DMRG across different materials studied?',
#   'type': 'abstractive',
#   'source': 'text-table'},
#  'bb566996-26ce-4c79-bde2-eeb77dadc939': {'query': 'How can $\\mathbb{E}\\left[Y(1)-Y(0) \\mid W^{*}=1\\right]$ be expressed?',
#   'type': 'extractive',
#   'source': 'text'},
#  '8a018d32-f56d-4b37-acc4-78c806628ac6': {'query': 'Is it possible for late-joining nodes to join after all previous nodes have crashed?',
#   'type': 'extractive',
#   'source': 'text'},
#  '03f507da-49d9-4bc8-aed1-fad06c18f576': {'query': 'What challenges do long-tailed distributions present in object detection tasks?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '93fb9188-7c53-4366-b440-0de589b16e95': {'query': 'What is the significance of weighted estimands in estimating treatment effects?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '200e0cd9-8e0b-4855-9beb-9bccb32eac08': {'query': 'Does each block in a blockchain contain transaction data and a reference to the preceding block?',
#   'type': 'extractive',
#   'source': 'text'},
#  '88c7356b-c189-4bb2-8895-19edae081ac9': {'query': 'What impact does training data bias have on generative chemical language models like GP-MOLFORMER?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '60ba9fa7-959a-4203-b1f8-f9a554e45d58': {'query': 'What modulation technique is used to analyze the impact of HPA-induced nonlinearities?',
#   'type': 'extractive',
#   'source': 'text'},
#  '59282ce9-2f66-41d7-bb4f-23ee9c85e04f': {'query': 'At what generation size does the novelty of both models start to decline significantly?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  '11a08b2c-4485-461f-bb2c-44ffed443c02': {'query': 'Does the band structure show instability towards an excitonic insulator state?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  'c7b59282-1a57-48c4-94eb-376bac609ad4': {'query': 'Why is there a spike at zero novelty in generated scaffolds?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '9f1c98d3-0f7f-4a7a-ac23-d2610968ba1c': {'query': 'Which images illustrate different stages of wavelet transformation?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '88d0b775-3bbb-4dec-8e59-e551ee9fc5c2': {'query': 'Does the foreground class distribution change between train and test sets?',
#   'type': 'extractive',
#   'source': 'text'},
#  'd371d40f-072e-4fbb-ae93-0ce9aef6c08e': {'query': 'Is the moment of inertia matrix for the quadrotor diagonal?',
#   'type': 'extractive',
#   'source': 'text'},
#  '0ae9f660-d60f-4217-9fe0-59f24f7bf82c': {'query': 'What is the purpose of using a contrastive loss function in the quantum multimodal contrastive learning framework?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '54c33d52-670c-4d3c-a2b4-bf3499c32878': {'query': 'How is canopy height mapping achieved using satellite imagery?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '71353019-0220-4d91-8103-64ee177eeb33': {'query': 'Why is it necessary to develop explainable AI schemes for future networks like 6G?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '5cc7172a-3e1d-4e09-8346-94b445c34a09': {'query': 'Is the quadratic form $\\gamma_{\\beta}^{2}$ of the regression coefficient vector identifiable from the system of moment equations?',
#   'type': 'extractive',
#   'source': 'text'},
#  'e6439ee4-abba-4275-aace-685701e575f9': {'query': 'Is model misspecification a concern when using parametric models like GLMs?',
#   'type': 'extractive',
#   'source': 'text'},
#  '92ef9a00-9690-4af1-b833-a7f9781670e1': {'query': 'What is the main purpose of the PyraNet dataset?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '09daf8be-22fa-4968-af27-fac050fb1372': {'query': 'Can the orientation $\\theta_e$ be used to construct angular filters for signal decomposition?',
#   'type': 'extractive',
#   'source': 'text'},
#  '0de1261b-8454-40b9-b81a-8505d89698a3': {'query': 'How does noise affect the accuracy of phase estimation in signals?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  'a299448a-a575-4c08-93d6-4c80d576b5a8': {'query': 'How do class and space calibrations differ in their impact on model accuracy?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  '779500be-2ca1-402d-9621-5ba2d1c4227f': {'query': 'What is the significance of the QNervFormer-GA model in EEG-based image recognition?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'b4bca301-33d1-46bf-b32c-aacd2bdb074d': {'query': 'How does Stubborn Nakamoto handle potential consistency violations differently from the original Nakamoto protocol?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '4094b7b1-489d-4e62-a2fd-6b37cd1ef208': {'query': 'What is the significance of using multiple subscales (K) in wavelet decomposition?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  'bb38513d-13ac-4b02-b4a7-246f67db2a7f': {'query': 'Can nodes freely enter and exit in a permissionless protocol?',
#   'type': 'extractive',
#   'source': 'text'},
#  'd6777c89-1808-4dcd-9f7a-9ad42e891081': {'query': 'Are the trajectory categories based on combinations of speed and curvature intervals?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  '2c874f4c-cac1-40f8-bb1d-ba72f07865df': {'query': 'What is the purpose of using phase demodulation in fingerprint registration?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  '58d5bbc8-1afe-4b08-8d85-c5cc61305093': {'query': 'Is the optimization problem for fine-tuning noise weight threshold convex?',
#   'type': 'extractive',
#   'source': 'text'},
#  '115fdbd6-df01-4cac-b1a2-c61161c7dc7c': {'query': 'Why is it beneficial for a channel estimation scheme to require fewer relevant subcarriers?',
#   'type': 'abstractive',
#   'source': 'text-table-image'},
#  'c7a64806-2c4f-4648-a78e-7be4cead4808': {'query': 'Can progress be made if the population covariance matrix is unknown?',
#   'type': 'extractive',
#   'source': 'text'},
#  '0a64c436-9590-487e-8676-05679ba526b0': {'query': 'What limitations exist in current datasets for biomass estimation from satellite imagery?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'f0ea57ab-5763-411d-93f4-637e3ea63c94': {'query': 'How does liveness ensure that the ledger keeps updating?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'bb4182bd-6a5b-42a9-ae8d-2e04cb13967f': {'query': 'How does ab initio downfolding help in simulating strongly-correlated materials?',
#   'type': 'abstractive',
#   'source': 'text'},
#  '8267956b-06c4-48fb-be1c-8d2d42c16374': {'query': 'Does the uniqueness of generated molecules reach near 100% at any point?',
#   'type': 'extractive',
#   'source': 'text-image'},
#  '8aa884c1-7102-4fe5-839c-2f8b7337f639': {'query': 'Why are quantum algorithms advantageous for studying compressed Hamiltonians?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'e53a5695-3f24-4b32-ae25-a12e7bb8ebb5': {'query': 'How are Wannier functions used in modeling materials?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '4bfdb5f7-7b83-4062-89eb-34e0530a7a89': {'query': 'Does the uniform distribution of \\(P\\) affect the calculation of \\(\\beta_{\\text{TWFE}}\\)?',
#   'type': 'extractive',
#   'source': 'text'},
#  '04759dbc-ec35-4d27-9bcc-db6fa47980e7': {'query': 'Is there an off-site Coulomb repulsion in the $\\mathrm{Ca}_{2} \\mathbf{CuO}_{3}$ system?',
#   'type': 'extractive',
#   'source': 'text'},
#  '7dc3e217-9ef3-4339-968d-0e64b5423a2e': {'query': 'What is the purpose of scrambling bits in OFDM transmission?',
#   'type': 'abstractive',
#   'source': 'text'},
#  'd158dbea-e21e-47e4-923f-dfe39bab9476': {'query': 'How large is the surface footprint scanned by the GEDI instrument?',
#   'type': 'extractive',
#   'source': 'text'},
#  '9c76b5bc-f200-429b-b0f2-a87c5de82cf3': {'query': 'What are piecewise polynomials and why are they used in quadrotor trajectory planning?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '3f2fb6cc-4979-44d5-9e80-364e66cfb24d': {'query': 'What are the key properties of strongly-correlated materials like $\\mathrm{Ca}_{2} \\mathrm{CuO}_{3}$, $\\mathrm{WTe}_{2}$, and $\\mathrm{SrVO}_{3}$?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '12b6c5f0-1061-4e79-b0a3-4ebdccbde1ad': {'query': 'Does PyraNet improve model performance compared to CodeLlama-7B?',
#   'type': 'extractive',
#   'source': 'text'},
#  'a2174fae-a8b3-48a0-bf21-4f2685eb6cb5': {'query': 'Why is it important to consider both speed and curvature when designing reference trajectories for quadrotors?',
#   'type': 'abstractive',
#   'source': 'text-image'},
#  '08c9a683-df57-4491-8056-5399b34a304d': {'query': 'Is the function for estimating causal effects dependent on both alpha and beta transposed with X?',
#   'type': 'extractive',
#   'source': 'text'},
#  '7638cdd2-2d50-4f18-8f90-b5a187125a8c': {'query': 'Does the Riesz transform perform a quadrature shift for phase estimation of i1D signals?',
#   'type': 'extractive',
#   'source': 'text'},
#  '40496897-59a3-4ec4-a3dd-67908efbaa15': {'query': 'What is the monogenic signal and how is it used in image processing?',
#   'type': 'abstractive',
#   'source': 'text'}}

# %%
import dotenv
import os
dotenv.load_dotenv('.env.host')

os.environ['MISTRAL_API_KEY'] = os.getenv('LLM_API_KEY')

# %%
print(judge.invoke("Say OK"))
# Out:
# content='OK! 😊' additional_kwargs={} response_metadata={'token_usage': {'prompt_tokens': 5, 'total_tokens': 11, 'completion_tokens': 6}, 'model_name': 'mistral-large-latest', 'model': 'mistral-large-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'} id='lc_run--019b1fc9-37c7-7441-8ae7-3a4b13d7a779-0' usage_metadata={'input_tokens': 5, 'output_tokens': 6, 'total_tokens': 11}

# %%
questions
# Out:
# {'3a004357-19ab-4ed6-b60c-02e419657cc4': 'What is the concept of location-class independence in object detection?',
#  '0dd5fa73-c74a-43cd-815b-5c1cb8d3d50a': 'Why is post-calibrated softmax adjustment (PCSA) important in handling class imbalances?',
#  'be608e3f-d284-4b13-b37d-5dd2571a8572': 'What does the term $p(y, o, u)$ represent in object detection?',
#  'ed761078-1f4b-45ec-a3f1-7084d2825171': 'Is there any significant relationship between geolocation error and performance in the updated GEDI dataset?',
#  '5a7d0a0b-d63d-4095-8c50-6a2f8f453554': 'How do bootstrap variance estimators compare to true variances in statistical studies?',
#  'dffc3d17-6be2-4ce4-81b3-5ca9d57d8abb': 'How is land cover classified in the Copernicus Global Land Service map?',
#  'a078059a-08f7-4bde-8488-329b3db39123': 'How does the structure multivector (SMV) improve spatial phase estimation?',
#  '637fdb28-12fb-472d-8d35-ea68a4ab77f6': 'Why is accurate estimation of Above Ground Biomass important for global challenges?',
#  'e80ec180-ea50-453b-bdce-96e0b346acaa': 'How can calibration techniques enhance the performance of machine learning models for detecting rare objects?',
#  '80e9d110-82af-41e5-8ad4-f084910c506e': 'Are there any interband contributions in the hopping terms for WTe2?',
#  '2edf284b-1689-4dc7-89d0-321935d60f18': 'What role does channel estimation play in enhancing the performance of smart applications in 6G networks?',
#  'f3b05e20-1008-43c6-9e21-ff8fed85156f': 'What do isotonic Single-Index Models (SIMs) allow for in comparison to GLMs?',
#  '0faca208-1f08-43ed-ace7-46ac1956e879': 'Can the Stubborn Nakamoto protocol regain liveness after an attack?',
#  '8c270ba7-7698-4fe5-82dc-4790162878e0': 'How does the SmoothInfo method improve upon traditional fractal dimension calculation techniques?',
#  '3e072125-e130-438c-b264-0bfb622cdf65': 'How are foreground and background predictions decoupled in binary classifiers?',
#  'b4595669-6205-48df-8fe6-c4a26a0ddfad': 'Can a PoS protocol regain liveness once an honest majority is restored?',
#  'ac71f2cd-5415-4a58-a032-634b08c2d8d9': 'Is the function $\\phi$ Hadamard directionally differentiable for all $\\theta \\in \\mathbb{R}^{K}$?',
#  '99f847b7-45cd-427c-8b12-70f3f293a025': 'What is the purpose of the FRACAL method in object detection?',
#  '4f54beeb-4760-487f-97dd-b794b9534c4c': 'Are closed forests the largest land cover type at the global scale?',
#  '4c1167ec-4f88-4e1c-a802-ce7ebf0e5f2a': 'How does Batch-DiffTune enhance robustness compared to DiffTune?',
#  '0817759c-e9ca-49a4-ba97-5f96044a9cde': 'What is required for a causal representation to exist for a given $\\tau_{0}$?',
#  'a0f6b046-11ba-4995-a431-7f716d9be58a': 'Can a weighted estimand always correspond to the target estimand a researcher is interested in?',
#  '01063042-ba62-4c90-8cb6-9ac5df7adb2a': 'What are the four main concepts defined by XAI?',
#  '0ba242ae-45e8-48d2-ad77-05c88d42f203': 'What is the significance of estimating regression coefficients in high-dimensional GLMs?',
#  '89c10cda-3293-4d74-82a0-9ada2e548949': 'Is the missing data mechanism assumed to be Missing-At-Random (MAR)?',
#  'ebafa50b-c5cc-4196-80f3-8aa3a348a5c4': 'What type of data does PALSAR-2 capture?',
#  '6f1e268c-3189-47a9-9500-fd6b10d27c62': 'What benefits does the XAI-CHEST framework offer over traditional deep learning-based channel estimation methods?',
#  'b88cab41-973b-4b16-9f5f-0d7aca565495': 'How often is Sentinel-2 data collected for use in the AGBD dataset?',
#  'aa7c0f53-8ac0-4f2a-9f13-1c35f6a6c457': 'Are gradient-based methods in XAI dependent on back-propagation?',
#  'f1f407f3-21b0-481d-93d5-3e8010fd46bd': 'What is the impact of unilateral divorce laws on female suicide rates in the U.S.?',
#  '8b0c6dc2-ffd5-4977-a56b-63c19f0c5e71': 'At what temperature does the validity of generated molecules remain consistently high?',
#  '842814ff-0d06-47a2-b79f-8ace2cf7d523': 'Is it possible for an estimand to have no causal representation over any regular subpopulation of $W_0$?',
#  'e8a2456e-90ce-488f-befc-521e1f75592c': 'What is the purpose of the TPN in model-based control?',
#  '71095b8c-1820-4ce6-81e4-2f8ebc84af96': 'What is the goal in maximizing $\\mathbb{P}\\left(W^{*}=1 \\mid W^{\\prime}=1\\right)$?',
#  '5f070211-03b6-4151-b128-7665d0538944': 'How many qubits are needed to simulate the properties of a Hubbard model on an \\(N_x \\times N_y\\) square lattice?',
#  'd9f19950-b63d-4b26-9e26-c12a8af30c92': 'How does the fine-scale fingerprint registration method perform under varying noise conditions?',
#  '05503af0-a4f2-4913-b78d-fbe630cc1396': 'Why is coherence important in estimating local structures within interference patterns?',
#  '7f6bab1b-3d4e-45d0-840e-92591419f931': "Can small miners contribute to a tragedy of the commons scenario in Bitcoin's protocol?",
#  '6af3388a-f97d-47b4-b9ab-92640dd11d41': 'What challenges arise when tuning control parameters for varying robot tasks?',
#  'a5baa057-111a-43d4-a8f6-92aeaa618934': 'What is the process for generating trajectory datasets for quadrotors?',
#  '4e78e3c2-d10c-4bbb-a908-44db042ee83f': 'What role do pilot subcarriers play in improving channel estimation accuracy?',
#  'fea1e036-994d-4ece-b172-296d94af1912': 'What is the significance of internal validity in weighted estimands?',
#  'aaef5819-4158-4103-a7e1-183a7a95b9b3': 'What is the significance of excitonic ground states in two-dimensional materials?',
#  'fc371482-b024-4274-bd67-d36c3620829b': 'Is consistency one of the properties required for correctness in consensus protocols?',
#  '53d86046-8b6a-4a48-8619-26b98338494e': 'What is the Task-Parameter Nexus approach in model-based control?',
#  '0eac8758-02f6-4ec3-82d9-3db7d406df47': 'Can TPN infer parameters for tasks not seen during training?',
#  'a78a905f-2df3-4f24-a145-577e0756bc70': 'What is the target of inference in the estimation of the Generalized Covariance Measure (GCM)?',
#  '8224e561-7ff0-4844-962d-b60d68e27f4c': 'How does the fidelity of VQE compare to DMRG across different materials studied?',
#  'bb566996-26ce-4c79-bde2-eeb77dadc939': 'How can $\\mathbb{E}\\left[Y(1)-Y(0) \\mid W^{*}=1\\right]$ be expressed?',
#  '8a018d32-f56d-4b37-acc4-78c806628ac6': 'Is it possible for late-joining nodes to join after all previous nodes have crashed?',
#  '03f507da-49d9-4bc8-aed1-fad06c18f576': 'What challenges do long-tailed distributions present in object detection tasks?',
#  '93fb9188-7c53-4366-b440-0de589b16e95': 'What is the significance of weighted estimands in estimating treatment effects?',
#  '200e0cd9-8e0b-4855-9beb-9bccb32eac08': 'Does each block in a blockchain contain transaction data and a reference to the preceding block?',
#  '88c7356b-c189-4bb2-8895-19edae081ac9': 'What impact does training data bias have on generative chemical language models like GP-MOLFORMER?',
#  '60ba9fa7-959a-4203-b1f8-f9a554e45d58': 'What modulation technique is used to analyze the impact of HPA-induced nonlinearities?',
#  '59282ce9-2f66-41d7-bb4f-23ee9c85e04f': 'At what generation size does the novelty of both models start to decline significantly?',
#  '11a08b2c-4485-461f-bb2c-44ffed443c02': 'Does the band structure show instability towards an excitonic insulator state?',
#  'c7b59282-1a57-48c4-94eb-376bac609ad4': 'Why is there a spike at zero novelty in generated scaffolds?',
#  '9f1c98d3-0f7f-4a7a-ac23-d2610968ba1c': 'Which images illustrate different stages of wavelet transformation?',
#  '88d0b775-3bbb-4dec-8e59-e551ee9fc5c2': 'Does the foreground class distribution change between train and test sets?',
#  'd371d40f-072e-4fbb-ae93-0ce9aef6c08e': 'Is the moment of inertia matrix for the quadrotor diagonal?',
#  '0ae9f660-d60f-4217-9fe0-59f24f7bf82c': 'What is the purpose of using a contrastive loss function in the quantum multimodal contrastive learning framework?',
#  '54c33d52-670c-4d3c-a2b4-bf3499c32878': 'How is canopy height mapping achieved using satellite imagery?',
#  '71353019-0220-4d91-8103-64ee177eeb33': 'Why is it necessary to develop explainable AI schemes for future networks like 6G?',
#  '5cc7172a-3e1d-4e09-8346-94b445c34a09': 'Is the quadratic form $\\gamma_{\\beta}^{2}$ of the regression coefficient vector identifiable from the system of moment equations?',
#  'e6439ee4-abba-4275-aace-685701e575f9': 'Is model misspecification a concern when using parametric models like GLMs?',
#  '92ef9a00-9690-4af1-b833-a7f9781670e1': 'What is the main purpose of the PyraNet dataset?',
#  '09daf8be-22fa-4968-af27-fac050fb1372': 'Can the orientation $\\theta_e$ be used to construct angular filters for signal decomposition?',
#  '0de1261b-8454-40b9-b81a-8505d89698a3': 'How does noise affect the accuracy of phase estimation in signals?',
#  'a299448a-a575-4c08-93d6-4c80d576b5a8': 'How do class and space calibrations differ in their impact on model accuracy?',
#  '779500be-2ca1-402d-9621-5ba2d1c4227f': 'What is the significance of the QNervFormer-GA model in EEG-based image recognition?',
#  'b4bca301-33d1-46bf-b32c-aacd2bdb074d': 'How does Stubborn Nakamoto handle potential consistency violations differently from the original Nakamoto protocol?',
#  '4094b7b1-489d-4e62-a2fd-6b37cd1ef208': 'What is the significance of using multiple subscales (K) in wavelet decomposition?',
#  'bb38513d-13ac-4b02-b4a7-246f67db2a7f': 'Can nodes freely enter and exit in a permissionless protocol?',
#  'd6777c89-1808-4dcd-9f7a-9ad42e891081': 'Are the trajectory categories based on combinations of speed and curvature intervals?',
#  '2c874f4c-cac1-40f8-bb1d-ba72f07865df': 'What is the purpose of using phase demodulation in fingerprint registration?',
#  '58d5bbc8-1afe-4b08-8d85-c5cc61305093': 'Is the optimization problem for fine-tuning noise weight threshold convex?',
#  '115fdbd6-df01-4cac-b1a2-c61161c7dc7c': 'Why is it beneficial for a channel estimation scheme to require fewer relevant subcarriers?',
#  'c7a64806-2c4f-4648-a78e-7be4cead4808': 'Can progress be made if the population covariance matrix is unknown?',
#  '0a64c436-9590-487e-8676-05679ba526b0': 'What limitations exist in current datasets for biomass estimation from satellite imagery?',
#  'f0ea57ab-5763-411d-93f4-637e3ea63c94': 'How does liveness ensure that the ledger keeps updating?',
#  'bb4182bd-6a5b-42a9-ae8d-2e04cb13967f': 'How does ab initio downfolding help in simulating strongly-correlated materials?',
#  '8267956b-06c4-48fb-be1c-8d2d42c16374': 'Does the uniqueness of generated molecules reach near 100% at any point?',
#  '8aa884c1-7102-4fe5-839c-2f8b7337f639': 'Why are quantum algorithms advantageous for studying compressed Hamiltonians?',
#  'e53a5695-3f24-4b32-ae25-a12e7bb8ebb5': 'How are Wannier functions used in modeling materials?',
#  '4bfdb5f7-7b83-4062-89eb-34e0530a7a89': 'Does the uniform distribution of \\(P\\) affect the calculation of \\(\\beta_{\\text{TWFE}}\\)?',
#  '04759dbc-ec35-4d27-9bcc-db6fa47980e7': 'Is there an off-site Coulomb repulsion in the $\\mathrm{Ca}_{2} \\mathbf{CuO}_{3}$ system?',
#  '7dc3e217-9ef3-4339-968d-0e64b5423a2e': 'What is the purpose of scrambling bits in OFDM transmission?',
#  'd158dbea-e21e-47e4-923f-dfe39bab9476': 'How large is the surface footprint scanned by the GEDI instrument?',
#  '9c76b5bc-f200-429b-b0f2-a87c5de82cf3': 'What are piecewise polynomials and why are they used in quadrotor trajectory planning?',
#  '3f2fb6cc-4979-44d5-9e80-364e66cfb24d': 'What are the key properties of strongly-correlated materials like $\\mathrm{Ca}_{2} \\mathrm{CuO}_{3}$, $\\mathrm{WTe}_{2}$, and $\\mathrm{SrVO}_{3}$?',
#  '12b6c5f0-1061-4e79-b0a3-4ebdccbde1ad': 'Does PyraNet improve model performance compared to CodeLlama-7B?',
#  'a2174fae-a8b3-48a0-bf21-4f2685eb6cb5': 'Why is it important to consider both speed and curvature when designing reference trajectories for quadrotors?',
#  '08c9a683-df57-4491-8056-5399b34a304d': 'Is the function for estimating causal effects dependent on both alpha and beta transposed with X?',
#  '7638cdd2-2d50-4f18-8f90-b5a187125a8c': 'Does the Riesz transform perform a quadrature shift for phase estimation of i1D signals?',
#  '40496897-59a3-4ec4-a3dd-67908efbaa15': 'What is the monogenic signal and how is it used in image processing?'}

# %%
questions = {k: v['query'] for k, v in val_queries.items()}

#для скорости возьмем первые 50 вопросов
result = eval_dataset(qids=list(questions.keys())[:50],
             questions=questions,
             contexts=retriever_contexts,
             answers=val_generate_answers,
             ground_truths=val_generate_ground_truths,
             tau=0.8)
# Out:
# 100%|██████████| 50/50 [05:06<00:00,  6.13s/it]

# %%
result
# Out:
# {'mean_correctness': 0.5299999999999999,
#  'task_success_rate': 0.22,
#  'mean_faithfulness': 0.424,
#  'hallucination_rate': 0.5760000000000001}

# %% [markdown]
# Здесь пока не очень удовлетворяющие нас значения метрик.
